# %%
import requests
import json

from config import key

# %%
earth_date = "2022-01-17"

target_url = f"https://api.nasa.gov/mars-photos/api/v1/rovers/curiosity/photos?api_key={key}&earth_date={earth_date}"

mars_data  = requests.get(target_url).json()

# Print the json
print(json.dumps(mars_data, indent=4, sort_keys=True))
# Out:
# {
#     "photos": [
#         {
#             "camera": {
#                 "full_name": "Front Hazard Avoidance Camera",
#                 "id": 20,
#                 "name": "FHAZ",
#                 "rover_id": 5
#             },
#             "earth_date": "2022-01-17",
#             "id": 921379,
#             "img_src": "https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03359/opgs/edr/fcam/FLB_695689884EDR_F0922650FHAZ00302M_.JPG",
#             "rover": {
#                 "id": 5,
#                 "landing_date": "2012-08-06",
#                 "launch_date": "2011-11-26",
#                 "name": "Curiosity",
#                 "status": "active"
#             },
#             "sol": 3359
#         },
#         {
#             "camera": {
#                 "full_name": "Front Hazard Avoidance Camera",
#                 "id": 20,
#                 "name": "FHAZ",
#                 "rover_id": 5
#             },
#             "earth_date": "2022-01-17",
# ...

# %%
print (len(mars_data['photos']))
# Out:
# 313

# %%
size = len(mars_data['photos'] - 1

# %%
for i in range(10):
    print ("i=",i)
    final_results = mars_data['photos'][i]
    for item in final_results.keys():
        print ("----")
        print(item)
        print(final_results[item])
        print('')
# Out:
# i= 0
# ----
# id
# 921379
#
# ----
# sol
# 3359
#
# ----
# camera
# {'id': 20, 'name': 'FHAZ', 'rover_id': 5, 'full_name': 'Front Hazard Avoidance Camera'}
#
# ----
# img_src
# https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03359/opgs/edr/fcam/FLB_695689884EDR_F0922650FHAZ00302M_.JPG
#
# ----
# earth_date
# 2022-01-17
#
# ----
# rover
# {'id': 5, 'name': 'Curiosity', 'landing_date': '2012-08-06', 'launch_date': '2011-11-26', 'status': 'active'}
#
# i= 1
# ----
# id
# 921380
#
# ----
# sol
# 3359
#
# ----
# camera
# {'id': 20, 'name': 'FHAZ', 'rover_id': 5, 'full_name': 'Front Hazard Avoidance Camera'}
#
# ----
# img_src
# https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03359/opgs/edr/fcam/FRB_695689884EDR_F0922650FHAZ00302M_.JPG
#
# ----
# earth_date
# 2022-01-17
#
# ----
# rover
# {'id': 5, 'name': 'Curiosity', 'landing_date': '2012-08-06', 'launch_date': '2011-11-26', 'status': 'active'}
#
# i= 2
# ----
# id
# 921381
#
# ----
# sol
# 3359
# ...

# %%
print (final_results)
# Out:
# [{'id': 921379, 'sol': 3359, 'camera': {'id': 20, 'name': 'FHAZ', 'rover_id': 5, 'full_name': 'Front Hazard Avoidance Camera'}, 'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03359/opgs/edr/fcam/FLB_695689884EDR_F0922650FHAZ00302M_.JPG', 'earth_date': '2022-01-17', 'rover': {'id': 5, 'name': 'Curiosity', 'landing_date': '2012-08-06', 'launch_date': '2011-11-26', 'status': 'active'}}, {'id': 921380, 'sol': 3359, 'camera': {'id': 20, 'name': 'FHAZ', 'rover_id': 5, 'full_name': 'Front Hazard Avoidance Camera'}, 'img_src': 'https://mars.nasa.gov/msl-raw-images/proj/msl/redops/ods/surface/sol/03359/opgs/edr/fcam/FRB_695689884EDR_F0922650FHAZ00302M_.JPG', 'earth_date': '2022-01-17', 'rover': {'id': 5, 'name': 'Curiosity', 'landing_date': '2012-08-06', 'launch_date': '2011-11-26', 'status': 'active'}}, {'id': 921381, 'sol': 3359, 'camera': {'id': 21, 'name': 'RHAZ', 'rover_id': 5, 'full_name': 'Rear Hazard Avoidance Camera'}, 'img_src': 'https://mars.nasa.g
# ...

# %%
for item in final_results.keys():
    print ("----")
    print(item)
    print(final_results[item])
    print('')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/mw/fkqfv6951kvf8qr6ycwfbk2m0000gp/T/ipykernel_1802/2194648361.py in <module>
# ----> 1 for item in final_results.keys():
#       2     print ("----")
#       3     print(item)
#       4     print(final_results[item])
#       5     print('')
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
start_date = "2022-01-01"
end_date = "2022-01-10"

target_url = f"https://api.nasa.gov/planetary/apod?api_key={key}&start_date={start_date}&end_date={end_date}"
earth_pictures  = requests.get(target_url).json()
# Print the json
print(json.dumps(earth_pictures, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "copyright": "Soumyadeep Mukherjee",
#         "date": "2022-01-01",
# ...
